# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/162.3 kB ? eta -:--:--
#      -------------- ---------------------- 61.4/162.3 kB 825.8 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/162.3 kB 657.6 kB/s eta 0:00:01
#      ------------------------------------ 162.3/162.3 kB 974.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 325.1 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 327.7 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 327.7 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 327.7 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 327.7 kB/s eta 0:00:01
# ...

# %%
int x=[4,6,8,9]
# Out:
#   Cell In[2], line 1
#     int x=[4,6,8,9]
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as pltx=[4,6,8,9,12,23]
y=x*4
# Out:
#   Cell In[3], line 1
#     import matplotlib.pyplot as pltx=[4,6,8,9,12,23]
#                                     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.49.0-cp310-cp310-win_amd64.whl.metadata (162 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# ...
# Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.49.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'C:\\Python310\\share\\man\\man1\\ttx.1'
# Consider using the `--user` option or check the permissions.
#
#
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
# Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
x=[4,6,8,9,12,23]
y=x**5

# %%
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 plt.plot(x,y)
#
# File C:\Python310\lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File C:\Python310\lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
# ...

# %%
plt.plot(y)

# %%
tempurtur = [0.5,0.56,0.7,0.6,0.43,0.76,0.5,0.26,0.7,0.54,0.5,0.56]
plt.plot(tempurtur,label='temp')
plt.title('Temperature for every month of the year')
plt.legend()

# %%
categories = ['chicken','Sweets','dairy','meat']
values = [23, 45, 56,76]
plt.bar(categories, values)
plt.title('Sales amount')
# Out:
# Text(0.5, 1.0, 'Sales amount')

# %%
plt.plot([100,   80,   89,   95,   82],   [2,   4,   6,  3,   7],   'r*')

# %%
plt.plot([100,   80,   89,   95,   82],   [2,   4,   6,  3,   7],   'r*')
plt.title('Study hours and student grades')
# Out:
# Text(0.5, 1.0, 'Study hours and student grades')

# %%
ages = [18, 21, 18, 32, 23, 26, 28, 26, 19, 24, 29, 17, 25, 31]
plt.hist(ages, bins=[10, 15, 20, 25, 30, 35], edgecolor='red')

plt.title('Ages of people in study group')
# Out:
# Text(0.5, 1.0, 'Ages of people in study group')

# %%
 years = range(2010, 2021)
 consumption_oil = [100, 105, 110, 120, 125, 130, 135, 140, 145, 150, 155]
 consumption_gas = [80, 82, 85, 88, 90, 95, 100, 105, 110, 115, 120]
 consumption_renewable = [20, 25, 30, 35, 40, 45, 50, 60, 70, 80, 90]
axs[0, 0].plot(years, consumption_oil, 'tab:blue')
axs[0, 0].set_title('Sin(years)')
axs[0, 1].plot(years, consumption_gas, 'tab:red')
axs[0, 1].set_title('Cos(years)')
axs[1, 0].scatter(years, consumption_renewable, c='yellow')
axs[1, 0].set_title('Sin(x) Scatter')
